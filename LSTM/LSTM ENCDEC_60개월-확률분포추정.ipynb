# %%
import os

import pandas as pd
import numpy as np
from numpy import array
import pandas_datareader.data as pdr 

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('seaborn-whitegrid')

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import plotly.express as px
import plotly.graph_objects as go
from scipy.ndimage import zoom

import seaborn as sns
plt.style.use('seaborn-whitegrid')
from pylab import rcParams
# %matplotlib inline
import itertools

import warnings 
warnings.filterwarnings(action='ignore')

import scipy.stats
from scipy.stats import norm,t

import math
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
#한글폰트 적용
import matplotlib.font_manager as fm
path = 'C:/Windows/Fonts/gulim.ttc'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('TEU_전국.csv')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
print(data.shape)
data.head()
# Out:
# (270, 10)
#                TEU   BDI  ln(HRCI)  ln(SCFI)  ln(다우존스지수)  전산업생산지수    경상수지  \
# Date
# 2000-01-31  570720  1319  1.913430  2.878875    4.039038     55.0  -218.1
# 2000-02-29  590400  1531  1.986905  2.882456    4.005537     51.9  -324.1
# 2000-03-31  665430  1660  2.050943  2.884831    4.038299     58.7   275.3
# 2000-04-30  603930  1628  2.107499  2.887110    4.030758     56.9 -1156.0
# 2000-05-31  683880  1566  2.158143  2.890466    4.022112     59.6  1535.5
#
#                  환율  화물수송총괄  수출물가지수
# Date
# 2000-01-31  1131.07  181367  133.88
# 2000-02-29  1128.80  218300  130.56
# 2000-03-31  1117.19  206116  128.19
# 2000-04-30  1109.76  166931  126.84
# 2000-05-31  1120.01  208853  127.89

# %%
split = -60
train_data = data['TEU'][0:split] 
test_data = data['TEU'][split:]

# %%
train_data.shape,test_data.shape
# Out:
# ((210,), (60,))

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('TEU')
plt.plot(data['TEU'], 'blue', label='TEU')
plt.legend()

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('TEU')
plt.plot(data['TEU'], 'blue', label='Train data')
plt.plot(test_data, 'red', label='Test data')
plt.legend()

# %%
seasonal = pd.read_csv('계절성예측.csv')

# %%
pd.set_option('display.max_columns', None)
trend = pd.read_csv('TEU분해.csv')
trend['Date'] = pd.to_datetime(trend['Date'])
trend = trend.set_index('Date')
print(trend.shape)
trend.head()
# Out:
# (60, 1)
#               TEU_Trend
# Date
# 2017-07-31  2291408.583
# 2017-08-31  2302073.625
# 2017-09-30  2310450.375
# 2017-10-31  2312407.958
# 2017-11-30  2320814.042

# %% [markdown]
# ### 2. 다변량 LSTM

# %%
import tensorflow 
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dense,Flatten,Dropout,GRU,Bidirectional,RepeatVector,TimeDistributed

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as K

# %%
import random
random.seed(1234)
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
tf.random.uniform([1]).numpy()
# Out:
# array([0.5380393], dtype=float32)

# %%
raw_df = data

# %%
split = -80
train = raw_df[0:split] 
test = raw_df[split:]

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('TEU')
plt.plot(train['TEU'], 'blue', label='Train data')
plt.plot(test['TEU'], 'red', label='Test data')
plt.legend()

# %%
len(train),len(test)
# Out:
# (190, 80)

# %%
data.columns
# Out:
# Index(['TEU', 'BDI', 'ln(HRCI)', 'ln(SCFI)', 'ln(다우존스지수)', '전산업생산지수', '경상수지',
#        '환율', '화물수송총괄', '수출물가지수'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scale_cols =  ['TEU','BDI', 'ln(HRCI)', 'ln(SCFI)','수출물가지수','환율','전산업생산지수','경상수지','ln(다우존스지수)','화물수송총괄']
scaled_train = scaler.fit_transform(train[scale_cols])  
scaled_train = pd.DataFrame(scaled_train, columns=scale_cols)

feature_train = scaled_train                       # X_train 다변량 시계열 변수 
label_train = scaled_train[['TEU']]               #  y_train 종속변수 

scaled_test = scaler.fit_transform(test[scale_cols]) 
scaled_test = pd.DataFrame(scaled_test, columns=scale_cols)

feature_test = scaled_test                       # X_test 다변량 시계열 변수 
label_test = scaled_test[['TEU']]               #  y_test종속변수

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        if out_end_ix > len(sequence):
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
window_size = 20 # Input Sequence (입력 길이) : X1,X2,....XT 
n_step_out = 60   # Output Sequence (출력 길이) : Y1,Y2,....YT

# %% [markdown]
# ### 1. X_train, Y_train 배열

# %%
X_train,y = split_sequence(feature_train, window_size, n_step_out) # feature_train = X 다변량 변수 
x, Y_train = split_sequence(label_train, window_size, n_step_out) # label_train = Y 종속변수 예측값

# %%
X_train.shape,Y_train.shape
# Out:
# ((111, 20, 10), (111, 60, 1))

# %% [markdown]
# ### 2. X_test,Y_test 배열

# %%
X_test,y = split_sequence(feature_test, window_size, n_step_out) # feature_train = X 다변량 변수 
x, Y_test = split_sequence(label_test, window_size, n_step_out) # label_train = Y 종속변수 예측값

# %%
X_test.shape,Y_test.shape
# Out:
# ((1, 20, 10), (1, 60, 1))

# %%
class MCDropout(Dropout): # 몬테카를로 드롭아웃 
    def call(self, inputs):
        return super().call(inputs, training=True)

# %%
model = Sequential() # Encoder & Decoder

## Encoder state
model.add(LSTM(64,activation='tanh',input_shape=(X_train.shape[1], X_train.shape[2]),return_sequences=False))
model.add(MCDropout(0.7))
model.add(Dense(1))
model.add(RepeatVector(60)) # 출력 개수만큼 반복 

## Decoder State
model.add(LSTM(64, activation='tanh', return_sequences=True)) # Decoder State 
model.add(MCDropout(0.7))
model.add(TimeDistributed(Dense(8,activation='relu'))) 
model.add(TimeDistributed(Dense(1)))

model.compile(loss='mean_squared_error', optimizer='adam',metrics='mae')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model.fit(X_train, Y_train, epochs= 200, batch_size=10, validation_split=0.02,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 11/11 [==============================] - 9s 436ms/step - loss: 0.3365 - mae: 0.5376 - val_loss: 0.1747 - val_mae: 0.3690
# Epoch 2/200
# 11/11 [==============================] - 0s 40ms/step - loss: 0.1006 - mae: 0.2512 - val_loss: 0.2444 - val_mae: 0.4647
# Epoch 3/200
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0735 - mae: 0.2187 - val_loss: 0.1056 - val_mae: 0.2760
# Epoch 4/200
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0581 - mae: 0.1914 - val_loss: 0.1533 - val_mae: 0.3619
# Epoch 5/200
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0482 - mae: 0.1753 - val_loss: 0.0752 - val_mae: 0.2323
# Epoch 6/200
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0429 - mae: 0.1652 - val_loss: 0.1056 - val_mae: 0.2829
# Epoch 7/200
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0362 - mae: 0.1496 - val_loss: 0.0937 - val_mae: 0.2722
# Epoch 8/200
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0320 - mae: 0.1394 - val_loss: 0.0436 - val_mae: 0.1654
# Epoch 9/200
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0289 - mae: 0.1343 - val_loss: 0.0479 - val_mae: 0.1804
# Epoch 10/200
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0257 - mae: 0.1257 - val_loss: 0.0541 - val_mae: 0.1879
# Epoch 11/200
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0273 - mae: 0.1297 - val_loss: 0.0457 - val_mae: 0.1760
# Epoch 12/200
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0229 - mae: 0.1192 - val_loss: 0.0370 - val_mae: 0.1572
# Epoch 13/200
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0212 - mae: 0.1153 - val_loss: 0.0317 - val_mae: 0.1445
# Epoch 14/200
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0197 - mae: 0.1093 - val_loss: 0.0333 - val_mae: 0.1502
# Epoch 15/200
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0192 - mae: 0.1090 - val_loss: 0.0364 - val_mae: 0.1526
# Epoch 16/200
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0188 - mae: 0.1075 - val_loss: 0.0410 - val_mae: 0.1714
# Epoch 17/200
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0165 - mae: 0.1000 - val_loss: 0.0307 - val_mae: 0.1431
# Epoch 18/200
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0157 - mae: 0.0966 - val_loss: 0.0303 - val_mae: 0.1378
# Epoch 19/200
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0179 - mae: 0.1039 - val_loss: 0.0324 - val_mae: 0.1485
# Epoch 20/200
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0157 - mae: 0.0974 - val_loss: 0.0329 - val_mae: 0.1515
# Epoch 21/200
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0154 - mae: 0.0976 - val_loss: 0.0371 - val_mae: 0.1625
# Epoch 22/200
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0150 - mae: 0.0946 - val_loss: 0.0285 - val_mae: 0.1362
# Epoch 23/200
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0147 - mae: 0.0935 - val_loss: 0.0285 - val_mae: 0.1426
# Epoch 24/200
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0140 - mae: 0.0915 - val_loss: 0.0215 - val_mae: 0.1192
# Epoch 25/200
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0140 - mae: 0.0922 - val_loss: 0.0228 - val_mae: 0.1248
# Epoch 26/200
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0124 - mae: 0.0867 - val_loss: 0.0248 - val_mae: 0.1252
# Epoch 27/200
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0121 - mae: 0.0856 - val_loss: 0.0211 - val_mae: 0.1189
# Epoch 28/200
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0121 - mae: 0.0845 - val_loss: 0.0203 - val_mae: 0.1147
# Epoch 29/200
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0124 - mae: 0.0862 - val_loss: 0.0302 - val_mae: 0.1464
# Epoch 30/200
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0118 - mae: 0.0846 - val_loss: 0.0214 - val_mae: 0.1186
# Epoch 31/200
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0116 - mae: 0.0846 - val_loss: 0.0267 - val_mae: 0.1424
# Epoch 32/200
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0122 - mae: 0.0856 - val_loss: 0.0226 - val_mae: 0.1194
# Epoch 33/200
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0112 - mae: 0.0826 - val_loss: 0.0235 - val_mae: 0.1210

# %%
X_test_1 = np.array(feature_test.head(20)).reshape((1,20, 10))

# %%
model_MC=  model
prediction = [model_MC.predict(X_test_1) for sample in range(30)]

# %%
dfs = [] # List 
for i in range(30): # 100번 반복 실험 
    fit = prediction[i].reshape(-1,1)
    fit_repeat = np.repeat(fit,10, axis=-1)
    model_fit = scaler.inverse_transform(fit_repeat)
    model_fit = np.squeeze(model_fit)[:,0]
    df = pd.DataFrame(model_fit)
    dfs.append(df)

# %%
rcParams['figure.figsize'] = 6, 2
plt.suptitle('MC-Dropout=0.5')
for i in range(0,30):
    plt.ylim(2.0e6,2.9e6)
    plt.plot(pd.DataFrame(np.array(dfs)[i]))

# %%
for i in range(0,30): # 1. df 
    df = pd.DataFrame(np.array(dfs)[i])

# %%
for i in range(0,30): # 2.df[i]
    df[i] = pd.DataFrame(np.array(dfs)[i])

# %%
df1 = df
df1.to_csv('df7.csv')

# %%
df1 = pd.read_csv('df1.csv')
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')
df4 = pd.read_csv('df4.csv')
df5 = pd.read_csv('df5.csv')
df6 = pd.read_csv('df6.csv')
df7 = pd.read_csv('df7.csv')
df8 = pd.read_csv('df8.csv')

# %%
plt.figure(figsize=(6.5,3))
plt.title('MC-Dropout Rate')
sns.distplot(df1,color='orange',hist=False,label='MCD=0.1')
sns.distplot(df2,color='cyan',hist=False,label='MCD=0.2')
sns.distplot(df3,color='green',hist=False,label='MCD=0.3')
sns.distplot(df4,color='lightgreen',hist=False,label='MCD=0.4')
sns.distplot(df5,color='violet',hist=False,label='MCD=0.5')
sns.distplot(df6,color='darkorange',hist=False,label='MCD=0.6')
sns.distplot(df7,color='dimgrey',hist=False,label='MCD=0.7')
sns.distplot(df8,color='blue',hist=False,label='MCD=0.8')
sns.distplot(test_data.reset_index()['TEU'],hist=False,color='red',label='TEU')
#plt.axvline(x=test_data.reset_index()['TEU'].mean(), ymax=0.24,color='red',linestyle='dashed',label='TEU Mean')
plt.legend()

# %%
plt.figure(figsize=(6.5,3))
plt.title('MC-Dropout Rate(LSTM)')
sns.distplot(df1,color='orange',hist=False,label='MCD=0.1')
sns.distplot(df2,color='cyan',hist=False,label='MCD=0.2')
sns.distplot(df3,color='green',hist=False,label='MCD=0.3')
sns.distplot(df4,color='lightgreen',hist=False,label='MCD=0.4')
sns.distplot(df5,color='violet',hist=False,label='MCD=0.5')
sns.distplot(df6,color='darkorange',hist=False,label='MCD=0.6')
sns.distplot(df7,color='dimgrey',hist=False,label='MCD=0.7')
sns.distplot(df8,color='blue',hist=False,label='MCD=0.8')
sns.distplot(test_data.reset_index()['TEU'],hist=False,color='red',label='TEU')
plt.xlabel('2017.07 ~ 2022.06 ')
plt.legend()

# %%
plt.title('MC-Dropout=0.8 Predictions & TEU Distribution')
sns.distplot(test_data.reset_index()['TEU'],hist=False,color='red')
sns.distplot(df6,hist=False,color='blue')
plt.axvline(x=test_data.reset_index()['TEU'].mean(), color='red',linestyle='dashed',label='TEU Mean')
plt.axvline(x=2351588.0, color='blue',linestyle='dashed',label='MLE Mean')
plt.legend()
